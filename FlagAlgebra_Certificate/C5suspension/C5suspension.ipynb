# %%
# Setting up three graph theory
K4m = ThreeGraphTheory(4, edges=[[0, 1, 2], [0, 2, 3], [0, 1, 3]])
sC5 = ThreeGraphTheory.p(6, edges=[[0, 1, 2], [0, 2, 3], [0, 3, 4], [0, 4, 5], [0, 5, 1]])
ThreeGraphTheory.exclude([K4m, sC5])
TGp = ThreeGraphTheory


# Testing the generation of structures
print("Number of structures without sC5, K4m")
print("and size 5: ", len(TGp.generate(5)))
print("and size 6: ", len(TGp.generate(6)))
print("and size 7: ", len(TGp.generate(7)))
# Out:
# Number of structures without sC5, K4m
# and size 5:  16
# and size 6:  151
# and size 7:  10440

# %%
TGp.optimize(TGp(3, edges=[[0, 1, 2]]), 7, exact=False, maximize=True, positives=[],
              construction=[], file="C5K3suspension_opt")
# Out:
# Base flags generated, their number is 10440
# The relevant ftypes are constructed, their number is 19
# Block sizes before symmetric/asymmetric change is applied: [6, 113, 68, 376, 279, 220, 210, 179, 160, 166, 101, 111, 152, 133, 98, 66, 52, 46, 26]
# Done with mult table for Ftype on 5 points with edges=(012 013 014 023 024 034 123 124 134 234): : 19it [03:53, 12.30s/it]
# Tables finished
# 0it [00:00, ?it/s]
# Constraints finished
# Running sdp without construction. Used block sizes are [6, 31, 82, 23, 45, 13, 363, 44, 235, 78, 142, 42, 168, 31, 148, 88, 72, 61, 105, 25, 76, 63, 48, 20, 132, 26, 107, 41, 57, 12, 54, 17, 35, 12, 34, 3, 23, -10440, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 9.07e-02 Pobj: -3.4280163e+01 Ad: 6.57e-02 Dobj:  1.7734384e+00
# Iter:  2 Ap: 8.73e-01 Pobj: -3.6556731e+02 Ad: 2.45e-01 Dobj:  8.6646729e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -6.2204299e+02 Ad: 6.98e-01 Dobj:  2.7274387e+00
# ...
