# %%
# Setting up {K_4^{3-}, C_5^{3-}}-free 3-graph theory
K4m = ThreeGraphTheory.p(4, edges=[[0, 1, 2], [0, 2, 3], [0, 1, 3]])
C5m = ThreeGraphTheory.p(5, edges=[[0, 1, 2], [1, 2, 3], [2, 3, 4], [3, 4, 0]])
ThreeGraphTheory.exclude([K4m, C5m])
TG = ThreeGraphTheory

print("Number of structures without K4m, C5m")
print("and size 5: ", len(TG.generate(5)))
print("and size 6: ", len(TG.generate(6)))
print("and size 7: ", len(TG.generate(7)))
# Out:
# Number of structures without K4m, C5m
# and size 5:  9
# and size 6:  55
# and size 7:  1127

# %%
# Setting up 3-colored {K_4^{3-}, C_5^{3-}}-free 3-graph theory

ThreeColorTheory = combine("3Colors", Color0, Color1, Color2, symmetries=NoSymmetry)
ThreeColorTheory.exclude([ThreeColorTheory(1), ThreeColorTheory.p(1, C0=[[0]], C1=[[0]]), 
                          ThreeColorTheory.p(1, C0=[[0]], C2=[[0]]), ThreeColorTheory.p(1, C1=[[0]], C2=[[0]])])
CTG = combine("3ColorThreeGraphs", TG, ThreeColorTheory)

print("\nNumber of 3 colored structures without K4m, C5m")
print("and size 5: ", len(CTG.generate(5)))
print("and size 6: ", len(CTG.generate(6)))
# Out:
# Number of 3 colored structures without K4m, C5m
# and size 5:  678
# and size 6:  16181

# %%
# Proposition 3.3: this part shows that the density of bad S_2 is at most 0.9*the density of missing S_2

target_size_3 = 6
assums_3 = []

# Edge density assumption from Turan theorem
E_total = CTG.p(3, edges = [[0,1,2]])
assums_3 += [1/4 - E_total]

# Edge-stability assumption from Proposition 3.2
# Missing edge with good colors
M = CTG(3, edges=[], C0=[0], C1=[1], C2=[2])
# Bad edges 
B = CTG(3, edges=[[0, 1, 2]], C0=[0,1], C1=[2]) 
B += CTG(3, edges=[[0, 1, 2]], C1=[0,1], C0=[2])
B += CTG(3, edges=[[0, 1, 2]], C1=[0,1], C2=[2])
B += CTG(3, edges=[[0, 1, 2]], C2=[0,1], C1=[2])
B += CTG(3, edges=[[0, 1, 2]], C2=[0,1], C0=[2])
B += CTG(3, edges=[[0, 1, 2]], C0=[0,1], C2=[2])
assums_3 += [(4/5)*M-B]

# max-cut ratio assumption from Proposition 3.1
C = CTG(3, edges=[[0, 1, 2]], C0=[0], C1=[1], C2=[2])
assums_3 += [C - 194/1000]

# size C0, C1, C2 assumptions derived from the max-cut ratio assumption
C0_size = CTG(1, C0=[0])
C1_size = CTG(1, C1=[0])
C2_size = CTG(1, C2=[0])
assums_3 += [C0_size - 1/5, 1/2 - C0_size, C1_size - 1/5, 1/2 - C1_size, C2_size - 1/5, 1/2 - C2_size]

# edges inside C0, C1, C2
E0 = CTG(3, edges=[[0, 1, 2]], C0=[0,1,2])
E1 = CTG(3, edges=[[0, 1, 2]], C1=[0,1,2])
E2 = CTG(3, edges=[[0, 1, 2]], C2=[0,1,2])
# non-edges inside C0, C1, C2
K0 = CTG(3, edges_m=[[0, 1, 2]], C0=[0,1,2])
K1 = CTG(3, edges_m=[[0, 1, 2]], C1=[0,1,2])
K2 = CTG(3, edges_m=[[0, 1, 2]], C2=[0,1,2])
# Edge density assumption inside each part follows from Turan theorem
assums_3 += [K0 - 3*E0, K1 - 3*E1, K2 - 3*E2]

# local maximality assumptions 
# Pointed edge with correct colors, point from color 0
Cp0 = CTG(3, edges=[[0, 1, 2]], C0=[0], C1=[1], C2=[2], ftype=[0])
# Pointed edge with bad colors, point from moving 1 -> 0
Bp01 = CTG(3, edges=[[0, 1, 2]], C0=[0,1], C1=[2], ftype=[0])
Bp02 = CTG(3, edges=[[0, 1, 2]], C0=[0,1], C2=[2], ftype=[0])

# Pointed edge with correct colors, point from color 1
Cp1 = CTG(3, edges=[[0, 1, 2]], C0=[0], C1=[1], C2=[2], ftype=[1])
# Pointed edge with bad colors, point from moving 1 -> 0
Bp11 = CTG(3, edges=[[0, 1, 2]], C0=[2], C1=[0, 1], ftype=[1])
Bp12 = CTG(3, edges=[[0, 1, 2]], C2=[2], C1=[0, 1], ftype=[1])

# Pointed edge with correct colors, point from color 2
Cp2 = CTG(3, edges=[[0, 1, 2]], C0=[0], C1=[1], C2=[2], ftype=[2])
# Pointed edge with bad colors, point from moving 1 -> 0
Bp21 = CTG(3, edges=[[0, 1, 2]], C0=[0], C2=[1, 2], ftype=[2])
Bp22 = CTG(3, edges=[[0, 1, 2]], C1=[0], C2=[1, 2], ftype=[2])

assums_3 += [Cp0-Bp01, Cp0-Bp02]
assums_3 += [Cp1-Bp11, Cp1-Bp12]
assums_3 += [Cp2-Bp21, Cp2-Bp22]

# Total S_2-density lower bound assumption 
S2_total = CTG.p(4, edges=[[0, 1, 2],[0, 1, 3]])
assums_3 += [6/13 - S2_total]
 
# Type-1 missing S3 (contains only one missing edge)
MS3 = CTG.p(5, edges=[[0, 1, 2],[0, 1, 3]], edges_m=[[0, 1, 4]], C0=[0], C1=[1], C2=[2,3,4])
MS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3]], edges_m=[[0, 1, 4]], C1=[0], C2=[1], C0=[2,3,4])
MS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3]], edges_m=[[0, 1, 4]], C2=[0], C0=[1], C1=[2,3,4])
# Type-2 missing S3 (contains two missing edges)
MS3 += CTG.p(5, edges=[[0, 1, 2]], edges_m=[[0, 1, 3], [0, 1, 4]], C0=[0], C1=[1], C2=[2,3,4])
MS3 += CTG.p(5, edges=[[0, 1, 2]], edges_m=[[0, 1, 3], [0, 1, 4]], C1=[0], C2=[1], C0=[2,3,4])
MS3 += CTG.p(5, edges=[[0, 1, 2]], edges_m=[[0, 1, 3], [0, 1, 4]], C2=[0], C0=[1], C1=[2,3,4])
# Type-3 missing S3 (contains two missing edges)
MS3 += CTG.p(5, edges_m=[[0, 1, 2],[0, 1, 3], [0, 1, 4]], C0=[0], C1=[1], C2=[2,3,4])
MS3 += CTG.p(5, edges_m=[[0, 1, 2],[0, 1, 3], [0, 1, 4]], C1=[0], C2=[1], C0=[2,3,4])
MS3 += CTG.p(5, edges_m=[[0, 1, 2],[0, 1, 3], [0, 1, 4]], C2=[0], C0=[1], C1=[2,3,4])

# Type-1 bad S3
BS3 = CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1,2,3], C1=[4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1,2,3], C2=[4], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1,2,3], C2=[4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1,2,3], C0=[4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1,2,3], C1=[4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1,2,3], C0=[4], C1=[])

# Type-2 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1,2], C1=[3], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1,2], C0=[3], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1,2], C0=[3], C1=[4])

# Type-3 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1,2], C1=[3,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1,2], C2=[3,4], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1,2], C0=[3,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1,2], C2=[3,4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1,2], C0=[3,4], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1,2], C1=[3,4], C0=[])

# Type-4 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1], C1=[2,3,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1], C2=[2,3,4], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1], C2=[2,3,4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1], C0=[2,3,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1], C1=[2,3,4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1], C0=[2,3,4], C1=[])

# Type-5 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1], C1=[2,3], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,1], C2=[2,3], C1=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1], C0=[2,3], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,1], C2=[2,3], C0=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1], C1=[2,3], C0=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,1], C0=[2,3], C1=[4])

# Type-6 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3,4], C1=[1], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3,4], C2=[1], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3,4], C0=[1], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3,4], C2=[1], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3,4], C1=[1], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3,4], C0=[1], C1=[])


# Type-7 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3], C1=[1], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3], C2=[1], C1=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3], C2=[1], C0=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3], C0=[1], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3], C1=[1], C0=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3], C0=[1], C1=[4])


# Type-8 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3], C1=[1,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2,3], C2=[1,4], C1=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3], C2=[1,4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2,3], C0=[1,4], C2=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3], C1=[1,4], C0=[])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2,3], C0=[1,4], C1=[])

# Type-9 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2], C1=[1], C2=[3,4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2], C2=[1], C1=[3,4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2], C2=[1], C0=[3,4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C1=[0,2], C0=[1], C2=[3,4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2], C1=[1], C0=[3,4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2], C0=[1], C1=[3,4])

# Type-10 bad S3
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2], C1=[1,3], C2=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C0=[0,2], C2=[1,3], C1=[4])
BS3 += CTG.p(5, edges=[[0, 1, 2],[0, 1, 3],[0, 1, 4]],  C2=[0,2], C1=[1,3], C0=[4])

symbolic_constr = CTG.blowup_construction(target_size_3, ["X0","X1","X2"], edges=[[0, 1, 2]], C0=[[0]], C1=[[1]], C2=[[2]], symbolic_parts=True).set_sum()
ders = symbolic_constr.derivatives([1/3, 1/3])

# %%
CTG.optimize(BS3-(1-1/100)*MS3, target_size_3, maximize=True,
              positives=assums_3, file="C5MinusL3Norm_Part3_BadMissingS3", 
                  exact=True, construction=ders, denom=2**10 * 225, slack_threshold=1e-6)
# Out:
# Base flags generated, their number is 16181
# The relevant ftypes are constructed, their number is 87
# Block sizes before symmetric/asymmetric change is applied: [57, 57, 57, 57, 57, 57, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
# Done with mult table for Ftype on 4 points with edges=(012 023), C0=(0 1 2 3), C1=(), C2=(): : 87it [00:16,  5.26it/s]
# Tables finished
# Done with positivity constraint 18: 100%|███████| 19/19 [03:08<00:00,  9.92s/it]
# Constraints finished
# Adjusting table with kernels from construction
# ...
