# %%
C53m = ThreeGraphTheory.p(5,edges =[[ 0, 1, 2 ], [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 3, 4 ]])
ThreeGraphTheory.exclude([C53m])

print("Number of structures without C53m")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without C53m
# and size 5:  16
# and size 6:  145

# %%
edge = ThreeGraphTheory(3, edges=[[0,1,2]])
ThreeGraphTheory.optimize(edge, 6,  exact=True,  file="C53m_edge",
              denom=1024*15, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00,  6.44it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -3.1290277e+01 Ad: 5.48e-01 Dobj:  7.1646476e-01
# Iter:  2 Ap: 1.00e+00 Pobj: -3.2976111e+01 Ad: 9.14e-01 Dobj: -1.7572511e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -3.4222998e+01 Ad: 9.21e-01 Dobj: -2.6267346e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -3.6449444e+01 Ad: 7.74e-01 Dobj: -2.5830234e-01
# Iter:  5 Ap: 4.84e-01 Pobj: -3.3627963e+01 Ad: 6.36e-01 Dobj: -2.3841985e-01
# ...

# %%
K43 = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [1,2,3], [0,2,3]])
ThreeGraphTheory.optimize(K43, 6,  exact=True,  file="C53m_K43",
              denom=1024*15, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 266.97it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -2.6884802e+01 Ad: 6.09e-01 Dobj: -1.8010380e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -2.8185531e+01 Ad: 9.27e-01 Dobj: -1.0206300e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -2.8806878e+01 Ad: 9.13e-01 Dobj: -1.6680711e-02
# Iter:  4 Ap: 1.00e+00 Pobj: -2.9931264e+01 Ad: 7.51e-01 Dobj: -1.1480330e-02
# Iter:  5 Ap: 3.98e-01 Pobj: -2.7399694e+01 Ad: 6.03e-01 Dobj: -1.0074700e-02
# ...

# %%
K43m = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [0,2,3]])
ThreeGraphTheory.optimize(K43m+4*K43, 6,  exact=True,  file="C53m_K43m", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 230.62it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -3.2526899e+01 Ad: 5.29e-01 Dobj: -7.4649070e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -3.4350080e+01 Ad: 9.10e-01 Dobj: -6.8915524e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -3.5818227e+01 Ad: 9.24e-01 Dobj: -1.5349607e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -3.8364818e+01 Ad: 7.76e-01 Dobj: -1.0277897e-01
# Iter:  5 Ap: 5.68e-01 Pobj: -3.5366090e+01 Ad: 6.53e-01 Dobj: -7.5070684e-02
# ...

# %%
# C53m = ThreeGraphTheory(5,edges =[[ 0, 1, 2 ], [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 3, 4 ]])


# ThreeGraphTheory.optimize(C53m+, 6,  exact=True,  file="C53m_C53m", 
#               denom=1024*15*3*5, slack_threshold=1e-6
#              )

# %%
# C53 = ThreeGraphTheory(5, edges=[[0, 1, 2], [1, 2, 3], [2, 3, 4], [3, 4, 0],[0,1,4]])

# ThreeGraphTheory.optimize(C53+, 6,  exact=True,  file="C53m_C53", 
#               denom=1024*15*3*5, slack_threshold=1e-6
#              )

# %%
# J4 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,2,3],[0,2,4],[0,3,4]])

# ThreeGraphTheory.optimize(J4+, 6,  exact=True,  file="C53m_J4", 
#               denom=1024*15*3*5, slack_threshold=1e-6
#              )

# %%
S2 = ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ]])
S2_0 = 3 * ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ], [ 1, 2, 3 ] ])
S2_1 = 6 * ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ], [ 1, 2, 3 ], [ 0, 2, 3 ] ])

ThreeGraphTheory.optimize(S2+S2_0 + S2_1, 6,  exact=True,  file="C53m_S2", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 88.52it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -5.8765018e+01 Ad: 3.59e-01 Dobj: -8.4016697e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -6.2183294e+01 Ad: 9.24e-01 Dobj: -1.0184413e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -6.4911376e+01 Ad: 9.29e-01 Dobj: -5.6825894e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -6.9329927e+01 Ad: 7.83e-01 Dobj: -4.5522030e-01
# Iter:  5 Ap: 5.93e-01 Pobj: -6.4359083e+01 Ad: 6.65e-01 Dobj: -3.7051384e-01
# ...

# %%
S3 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3],[0,1,4]])
S3_0 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ] ])
S3_1 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 2, 3, 4 ] ])
S3_2 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ] ])
S3_3 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 1, 3, 4 ] ])
S3_4 = 4 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 0, 2, 4 ] ])

ThreeGraphTheory.optimize(S3+S3_0 + S3_1 + S3_2 + S3_3 + S3_4, 6,  exact=True,  file="C53m_S3", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 77.96it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -8.9192088e+01 Ad: 2.60e-01 Dobj: -4.0932044e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -9.4409697e+01 Ad: 9.40e-01 Dobj: -1.1181804e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -9.8067283e+01 Ad: 9.26e-01 Dobj: -4.6679110e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -1.0475212e+02 Ad: 7.80e-01 Dobj: -2.8480679e-01
# Iter:  5 Ap: 4.93e-01 Pobj: -9.7224692e+01 Ad: 6.50e-01 Dobj: -1.5303625e-01
# ...

# %%
S4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ]])
S4_0 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ] ])
S4_1 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ] ])
S4_2 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ] ])
S4_3 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 2, 5 ] ])
S4_4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ] ])
S4_5 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ] ])
S4_6 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 4 ] ])
S4_7 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ] ])
S4_8 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 5 ] ])
S4_9 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_10 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_11 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_12 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_13 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_14 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ], [ 1, 3, 4 ] ])
S4_15 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_16 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 1, 3, 4 ] ])
S4_17 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_18 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_19 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 3, 5 ] ])
S4_20 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ], [ 1, 3, 4 ] ])
S4_21 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_22 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 0, 2, 3 ] ])
S4_23 = 5 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ] ])

ThreeGraphTheory.optimize(S4+S4_0 + S4_1 + S4_2 + S4_3 + S4_4 + S4_5 + S4_6 + S4_7 + S4_8 + S4_9 + S4_10 + S4_11 + S4_12 + S4_13 + S4_14 + S4_15 + S4_16 + S4_17 + S4_18 + S4_19 + S4_20 + S4_21 + S4_22 + S4_23,
                          6,  exact=True,  file="C53m_S4", denom=1024*1024, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 145
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 39, 20, 11, 7]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 254.43it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 13, 26, 10, 10, 5, 6, 2, 5, -145, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -1.2834015e+02 Ad: 1.91e-01 Dobj: -1.3806010e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.3589931e+02 Ad: 9.46e-01 Dobj: -2.5519717e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -1.4109555e+02 Ad: 9.27e-01 Dobj: -5.6441002e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -1.5011932e+02 Ad: 7.79e-01 Dobj: -2.7194356e-01
# Iter:  5 Ap: 4.77e-01 Pobj: -1.3947675e+02 Ad: 6.49e-01 Dobj: -9.1910734e-02
# ...
