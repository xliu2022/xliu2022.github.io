# %%
J4 = ThreeGraphTheory.p(5, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,2,3],[0,2,4],[0,3,4]])
F32 = ThreeGraphTheory.p(5, edges=[[0, 1, 2], [0, 1, 3], [0, 1, 4], [2, 3, 4]])

ThreeGraphTheory.exclude([F32,J4])

print("Number of structures without J4 and F32")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without J4 and F32
# and size 5:  21
# and size 6:  409

# %%
edge = ThreeGraphTheory(3, edges=[[0,1,2]])
ThreeGraphTheory.optimize(edge, 6,  exact=True,  file="J4F32_edge",
              denom=1024*15, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 49.17it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -4.1465715e+01 Ad: 5.07e-01 Dobj:  2.5779832e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -4.3368252e+01 Ad: 9.43e-01 Dobj: -1.1089973e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -4.3570692e+01 Ad: 9.31e-01 Dobj: -3.3026166e-01
# Iter:  4 Ap: 9.06e-01 Pobj: -4.6467326e+01 Ad: 7.97e-01 Dobj: -3.3607743e-01
# Iter:  5 Ap: 8.09e-01 Pobj: -5.0623849e+01 Ad: 6.02e-01 Dobj: -3.1535845e-01
# ...

# %%
K43 = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [1,2,3], [0,2,3]])
ThreeGraphTheory.optimize(K43, 6,  exact=True,  file="J4F32_K43",
              denom=1024*15, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 49.72it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -3.8811557e+01 Ad: 5.33e-01 Dobj: -5.7278562e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -4.0528824e+01 Ad: 9.43e-01 Dobj: -3.1141179e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -4.0631669e+01 Ad: 9.31e-01 Dobj: -7.1100108e-02
# Iter:  4 Ap: 9.48e-01 Pobj: -4.3497583e+01 Ad: 7.86e-01 Dobj: -2.9516724e-02
# Iter:  5 Ap: 7.72e-01 Pobj: -4.6638007e+01 Ad: 6.04e-01 Dobj: -2.4443237e-02
# ...

# %%
K43m = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [0,2,3]])
ThreeGraphTheory.optimize(K43m+4*K43, 6,  exact=True,  file="J4F32_K43m", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 47.65it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -4.5332579e+01 Ad: 4.73e-01 Dobj: -2.1313026e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -4.7484292e+01 Ad: 9.43e-01 Dobj: -1.1732566e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -4.7850489e+01 Ad: 9.33e-01 Dobj: -3.7808625e-01
# Iter:  4 Ap: 8.61e-01 Pobj: -5.0799186e+01 Ad: 8.06e-01 Dobj: -1.9840499e-01
# Iter:  5 Ap: 8.69e-01 Pobj: -5.6314604e+01 Ad: 6.18e-01 Dobj: -1.5855300e-01
# ...

# %%
C53m = ThreeGraphTheory(5,edges =[[ 0, 1, 2 ], [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 3, 4 ]])
C53m_0 = 5 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 1, 4 ] ])
C53m_1 = 1 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ] ])
C53m_2 = 2 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 4 ] ])
C53m_3 = 2 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 0, 2, 4 ] ])
C53m_4 = 6 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 1, 3 ] ])
C53m_5 = 6 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 0, 2, 4 ], [ 0, 1, 3 ] ])

ThreeGraphTheory.optimize(C53m+C53m_0 + C53m_1 + C53m_2 + C53m_3 + C53m_4 + C53m_5, 6,  exact=True,  file="J4F32_C53m", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 47.13it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 9.54e-01 Pobj: -1.4103815e+02 Ad: 1.94e-01 Dobj: -5.8089656e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.5982783e+02 Ad: 8.84e-01 Dobj: -1.8562966e+01
# Iter:  3 Ap: 1.00e+00 Pobj: -1.6664912e+02 Ad: 9.43e-01 Dobj: -1.9106231e+00
# Iter:  4 Ap: 1.00e+00 Pobj: -1.6333277e+02 Ad: 8.76e-01 Dobj: -8.4976171e-01
# Iter:  5 Ap: 1.00e+00 Pobj: -1.9221194e+02 Ad: 6.01e-01 Dobj: -6.2430774e-01
# ...

# %%
C53 = ThreeGraphTheory(5, edges=[[0, 1, 2], [1, 2, 3], [2, 3, 4], [3, 4, 0],[0,1,4]])

ThreeGraphTheory.optimize(C53, 6,  exact=True,  file="J4F32_C53", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 46.93it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 9.99e-01 Pobj: -4.3269571e+01 Ad: 4.82e-01 Dobj: -2.1676637e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -4.5566876e+01 Ad: 9.41e-01 Dobj: -1.7354422e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -4.5811469e+01 Ad: 9.30e-01 Dobj: -1.9064337e-02
# Iter:  4 Ap: 9.01e-01 Pobj: -4.8685085e+01 Ad: 8.14e-01 Dobj: -2.1273471e-02
# Iter:  5 Ap: 8.97e-01 Pobj: -5.4415598e+01 Ad: 5.98e-01 Dobj: -2.2223321e-02
# ...

# %%
# J4 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,2,3],[0,2,4],[0,3,4]])

# ThreeGraphTheory.optimize(J4+, 6,  exact=True,  file="K43mC53_J4", 
#               denom=1024*15*3*5, slack_threshold=1e-6
#              )

# %%
S2 = ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ]])
S2_0 = 3 * ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ], [ 1, 2, 3 ] ])
S2_1 = 6 * ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ], [ 1, 2, 3 ], [ 0, 2, 3 ] ])

ThreeGraphTheory.optimize(S2+S2_0+S2_1, 6,  exact=True,  file="J4F32_S2", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 46.11it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -7.6404011e+01 Ad: 3.35e-01 Dobj: -1.3740653e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -7.9971278e+01 Ad: 9.31e-01 Dobj: -1.7703546e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -8.1697129e+01 Ad: 9.41e-01 Dobj: -9.7467444e-01
# Iter:  4 Ap: 8.85e-01 Pobj: -8.4534806e+01 Ad: 8.43e-01 Dobj: -7.5773868e-01
# Iter:  5 Ap: 1.00e+00 Pobj: -9.6602159e+01 Ad: 6.78e-01 Dobj: -6.3976922e-01
# ...

# %%
S3 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3],[0,1,4]])
S3_0 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ] ])
S3_1 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ] ])
S3_2 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 1, 2, 4 ] ])
S3_3 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 1, 3, 4 ] ])
S3_4 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 1, 2, 3 ] ])
S3_5 = 3 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 1, 2, 3 ], [ 1, 3, 4 ] ])

ThreeGraphTheory.optimize(S3+S3_0 + S3_1 + S3_2 + S3_3 + S3_4 + S3_5, 6,  exact=True,  file="J4F32_S3", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 45.42it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -6.9205193e+01 Ad: 3.59e-01 Dobj: -1.2866926e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -7.2445723e+01 Ad: 9.37e-01 Dobj: -6.1027201e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -7.3852386e+01 Ad: 9.43e-01 Dobj: -6.4151667e-01
# Iter:  4 Ap: 8.64e-01 Pobj: -7.6617539e+01 Ad: 8.25e-01 Dobj: -3.9893704e-01
# Iter:  5 Ap: 1.00e+00 Pobj: -8.6884775e+01 Ad: 6.89e-01 Dobj: -3.1085357e-01
# ...

# %%
S4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ]])
S4_0 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ] ])
S4_1 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ] ])
S4_2 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ] ])
S4_3 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 2, 5 ] ])
S4_4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ] ])
S4_5 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 4 ] ])
S4_6 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ] ])
S4_7 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ] ])
S4_8 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ] ])
S4_9 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 3 ] ])
S4_10 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 5 ] ])
S4_11 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_12 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_13 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ] ])
S4_14 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_15 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 3, 5 ] ])
S4_16 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 4 ] ])
S4_17 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ] ])
S4_18 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 3, 5 ] ])
S4_19 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 1, 3, 4 ] ])
S4_20 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ], [ 0, 2, 3 ] ])
S4_21 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ], [ 1, 2, 3 ] ])
S4_22 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ], [ 1, 3, 4 ] ])
S4_23 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 1, 3, 4 ] ])
S4_24 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_25 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ] ])
S4_26 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 3, 5 ] ])
S4_27 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 1, 2, 4 ] ])
S4_28 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 1, 3, 4 ] ])
S4_29 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_30 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ], [ 0, 2, 3 ], [ 1, 2, 3 ] ])
S4_31 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_32 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 2, 4 ] ])
S4_33 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 3, 4 ] ])
S4_34 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 3, 5 ], [ 1, 3, 4 ] ])
S4_35 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 1, 2, 4 ], [ 1, 3, 4 ] ])
S4_36 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 3, 5 ], [ 0, 2, 3 ], [ 1, 2, 3 ], [ 1, 3, 4 ] ])
S4_37 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 1, 2, 4 ] ])
S4_38 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 1, 2, 4 ], [ 1, 3, 4 ] ])

ThreeGraphTheory.optimize(S4+S4_0 + S4_1 + S4_2 + S4_3 + S4_4 + S4_5 + S4_6 + S4_7 + S4_8 + S4_9 + S4_10 + S4_11 + S4_12 + S4_13 + S4_14 + S4_15 + S4_16 + S4_17 + S4_18 + S4_19 + S4_20 + S4_21 + S4_22 + S4_23 + S4_24 + S4_25 + S4_26 + S4_27 + S4_28 + S4_29 + S4_30 + S4_31 + S4_32 + S4_33 + S4_34 + S4_35 + S4_36 + S4_37 + S4_38,
                          6,  exact=True,  file="J4F32_S4", denom=1024*1024, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 409
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 63, 56, 41, 23, 23]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00, 43.44it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 10, 53, 16, 40, 18, 23, 8, 15, 4, 19, -409, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 9.95e-01 Pobj: -9.2329445e+01 Ad: 2.89e-01 Dobj: -3.9971662e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -9.7349424e+01 Ad: 9.24e-01 Dobj: -7.7364724e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -9.9929727e+01 Ad: 9.42e-01 Dobj: -8.4493379e-01
# Iter:  4 Ap: 9.16e-01 Pobj: -1.0211154e+02 Ad: 8.59e-01 Dobj: -2.5863555e-01
# Iter:  5 Ap: 1.00e+00 Pobj: -1.1728829e+02 Ad: 6.10e-01 Dobj: -1.7183151e-01
# ...
