# %%
K43 = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [1,2,3], [0,2,3]])
ThreeGraphTheory.exclude([K43])

print("Number of structures without K43")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without K43
# and size 5:  23
# and size 6:  964

# %%
edge = ThreeGraphTheory(3, edges=[[0,1,2]])
ThreeGraphTheory.optimize(edge, 6,  exact=True,  file="K43_edge",
              denom=1024*15, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 16.18it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 9.00e-01 Pobj: -5.6705804e+01 Ad: 3.90e-01 Dobj:  8.9763931e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -7.0559583e+01 Ad: 9.05e-01 Dobj:  1.0763286e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -7.1817481e+01 Ad: 9.19e-01 Dobj: -2.6064380e-01
# Iter:  4 Ap: 9.38e-01 Pobj: -6.5205022e+01 Ad: 9.45e-01 Dobj: -3.4835075e-01
# Iter:  5 Ap: 8.35e-01 Pobj: -6.2193888e+01 Ad: 6.77e-01 Dobj: -3.9356028e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -6.1547054e+01 Ad: 5.99e-01 Dobj: -3.9984094e-01
# ...

# %%
# K43 = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [1,2,3], [0,2,3]])
# ThreeGraphTheory.optimize(K43, 6,  exact=True,  file="K43_K43",
#               denom=1024*15, slack_threshold=1e-6
#              )

# %%
K43m = ThreeGraphTheory(4, edges=[[0,1,2], [0,1,3], [0,2,3]])
ThreeGraphTheory.optimize(K43m, 6,  exact=True,  file="K43_K43m", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 15.15it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.94e-01 Pobj: -5.6467390e+01 Ad: 3.88e-01 Dobj: -6.5602710e-01
# Iter:  2 Ap: 1.00e+00 Pobj: -7.1613241e+01 Ad: 9.00e-01 Dobj: -1.0295139e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -7.3018249e+01 Ad: 9.15e-01 Dobj: -2.8408360e-01
# Iter:  4 Ap: 9.62e-01 Pobj: -6.6071214e+01 Ad: 9.44e-01 Dobj: -2.1337052e-01
# Iter:  5 Ap: 8.57e-01 Pobj: -6.3596515e+01 Ad: 6.93e-01 Dobj: -2.0927128e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -6.4857388e+01 Ad: 5.97e-01 Dobj: -2.1121479e-01
# ...

# %%
C53m = ThreeGraphTheory(5,edges =[[ 0, 1, 2 ], [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 3, 4 ]])
C53m_0 = 5 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 1, 4 ] ])
C53m_1 = 1 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ] ])
C53m_2 = 2 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 1, 2, 4 ] ])
C53m_3 = 2 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 4 ] ])
C53m_4 = 7 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 1, 4 ], [ 0, 2, 3 ] ])
C53m_5 = 4 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])
C53m_6 = 6 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 1, 3 ] ])
C53m_7 = 14 * ThreeGraphTheory(5,edges =[ [ 1, 2, 3 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 1, 4 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])

ThreeGraphTheory.optimize(C53m+C53m_0 + C53m_1 + C53m_2 + C53m_3 + C53m_4 + C53m_5 + C53m_6 + C53m_7, 6,  exact=True,  file="K43_C53m", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 16.77it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.14e-01 Pobj: -4.5026945e+02 Ad: 5.68e-02 Dobj: -4.8747510e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -5.7786265e+02 Ad: 8.41e-01 Dobj: -2.8922562e+01
# Iter:  3 Ap: 1.00e+00 Pobj: -6.0293008e+02 Ad: 9.39e-01 Dobj: -2.5608151e+00
# Iter:  4 Ap: 1.00e+00 Pobj: -5.4994098e+02 Ad: 9.48e-01 Dobj: -1.5542132e+00
# Iter:  5 Ap: 7.49e-01 Pobj: -5.0298960e+02 Ad: 7.99e-01 Dobj: -1.5933252e+00
# Iter:  6 Ap: 1.00e+00 Pobj: -5.3029277e+02 Ad: 6.02e-01 Dobj: -1.5701394e+00
# ...

# %%
C53 = ThreeGraphTheory(5, edges=[[0, 1, 2], [1, 2, 3], [2, 3, 4], [3, 4, 0],[0,1,4]])
C53_0 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 3, 4 ], [ 0, 1, 4 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 1, 2, 3 ], [ 0, 2, 3 ] ])
C53_1 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 3, 4 ], [ 0, 1, 4 ], [ 2, 3, 4 ], [ 0, 1, 2 ], [ 1, 2, 3 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])

ThreeGraphTheory.optimize(C53+C53_0+C53_1, 6,  exact=True,  file="K43_C53", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 14.04it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.62e-01 Pobj: -8.6743541e+01 Ad: 2.73e-01 Dobj: -1.6852385e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.1143903e+02 Ad: 8.94e-01 Dobj:  1.4256859e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -1.1346309e+02 Ad: 9.25e-01 Dobj: -7.6365091e-02
# Iter:  4 Ap: 9.62e-01 Pobj: -1.0316414e+02 Ad: 9.45e-01 Dobj: -1.3358969e-01
# Iter:  5 Ap: 9.03e-01 Pobj: -1.0012433e+02 Ad: 7.15e-01 Dobj: -1.3166901e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -1.0466629e+02 Ad: 6.00e-01 Dobj: -1.2822085e-01
# ...

# %%
J4 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,2,3],[0,2,4],[0,3,4]])

ThreeGraphTheory.optimize(J4, 6,  exact=True,  file="K43_J4", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 16.56it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.82e-01 Pobj: -5.5471549e+01 Ad: 3.88e-01 Dobj: -1.1742354e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -7.2052942e+01 Ad: 8.95e-01 Dobj: -2.8879552e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -7.3682739e+01 Ad: 9.11e-01 Dobj: -2.9396046e-01
# Iter:  4 Ap: 9.92e-01 Pobj: -6.6632616e+01 Ad: 9.43e-01 Dobj: -5.3603045e-02
# Iter:  5 Ap: 9.04e-01 Pobj: -6.4771922e+01 Ad: 7.09e-01 Dobj: -2.6022236e-02
# Iter:  6 Ap: 1.00e+00 Pobj: -6.8934919e+01 Ad: 5.91e-01 Dobj: -2.1959680e-02
# ...

# %%
S2 = ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ]])
S2_0 = 3 * ThreeGraphTheory(4,edges =[ [ 0, 1, 3 ], [ 0, 1, 2 ], [ 1, 2, 3 ] ])

ThreeGraphTheory.optimize(S2+S2_0, 6,  exact=True,  file="K43_S2", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 14.09it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.52e-01 Pobj: -1.0590991e+02 Ad: 2.31e-01 Dobj:  4.5443931e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -1.3572373e+02 Ad: 8.76e-01 Dobj:  8.3303228e-01
# Iter:  3 Ap: 1.00e+00 Pobj: -1.3893537e+02 Ad: 9.34e-01 Dobj: -7.4630680e-01
# Iter:  4 Ap: 9.91e-01 Pobj: -1.2576333e+02 Ad: 9.45e-01 Dobj: -8.7754631e-01
# Iter:  5 Ap: 9.35e-01 Pobj: -1.2280539e+02 Ad: 7.23e-01 Dobj: -9.6670824e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -1.3306756e+02 Ad: 6.02e-01 Dobj: -9.7366912e-01
# ...

# %%
S3 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3],[0,1,4]])
S3_0 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ] ])
S3_1 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 2, 3, 4 ] ])
S3_2 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 2, 3, 4 ] ])
S3_3 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ] ])
S3_4 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 1, 2, 4 ] ])
S3_5 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 3 ] ])
S3_6 = 1 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 1, 2, 4 ] ])
S3_7 = 4 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 0, 2, 3 ], [ 0, 2, 4 ] ])
S3_8 = 2 * ThreeGraphTheory(5,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])

ThreeGraphTheory.optimize(S3+S3_0 + S3_1 + S3_2 + S3_3 + S3_4 + S3_5 + S3_6 + S3_7 + S3_8, 6,  exact=True,  file="K43_S3", 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 16.37it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.25e-01 Pobj: -1.2518669e+02 Ad: 1.93e-01 Dobj:  7.9326960e+00
# Iter:  2 Ap: 1.00e+00 Pobj: -1.6430258e+02 Ad: 8.64e-01 Dobj:  7.2575119e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -1.6897233e+02 Ad: 9.34e-01 Dobj: -5.0769484e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -1.5321728e+02 Ad: 9.45e-01 Dobj: -6.9389336e-01
# Iter:  5 Ap: 8.42e-01 Pobj: -1.4602116e+02 Ad: 7.54e-01 Dobj: -6.5555629e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -1.5729397e+02 Ad: 6.00e-01 Dobj: -6.6025379e-01
# ...

# %%
S4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ]])
S4_0 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ] ])
S4_1 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ] ])
S4_2 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ] ])
S4_3 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ] ])
S4_4 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ] ])
S4_5 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 2, 5 ] ])
S4_6 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ] ])
S4_7 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ] ])
S4_8 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ] ])
S4_9 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ] ])
S4_10 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ] ])
S4_11 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ] ])
S4_12 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 4, 5 ] ])
S4_13 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 3 ] ])
S4_14 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 4, 5 ] ])
S4_15 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 3, 4, 5 ] ])
S4_16 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ] ])
S4_17 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 1, 2, 5 ] ])
S4_18 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 4 ] ])
S4_19 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ] ])
S4_20 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 2, 4, 5 ] ])
S4_21 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 3, 4, 5 ] ])
S4_22 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_23 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_24 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_25 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_26 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_27 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_28 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ] ])
S4_29 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ] ])
S4_30 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ] ])
S4_31 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ] ])
S4_32 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ] ])
S4_33 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 4 ] ])
S4_34 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 4, 5 ] ])
S4_35 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ] ])
S4_36 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 3, 5 ] ])
S4_37 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 3, 4, 5 ] ])
S4_38 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 3 ] ])
S4_39 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_40 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 4, 5 ] ])
S4_41 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 3 ] ])
S4_42 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 2, 4 ] ])
S4_43 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ] ])
S4_44 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 1, 4, 5 ] ])
S4_45 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 3 ] ])
S4_46 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 2, 4, 5 ] ])
S4_47 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 3, 4, 5 ] ])
S4_48 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 1, 2, 3 ] ])
S4_49 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_50 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ] ])
S4_51 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_52 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_53 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 3, 5 ] ])
S4_54 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 4, 5 ] ])
S4_55 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 3, 4, 5 ] ])
S4_56 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ] ])
S4_57 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 3, 4, 5 ] ])
S4_58 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_59 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_60 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 0, 4, 5 ] ])
S4_61 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 2, 4, 5 ] ])
S4_62 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 2, 3, 5 ] ])
S4_63 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_64 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_65 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_66 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_67 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 3, 5 ] ])
S4_68 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ] ])
S4_69 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ] ])
S4_70 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ] ])
S4_71 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 4 ] ])
S4_72 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ] ])
S4_73 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 4, 5 ] ])
S4_74 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 3, 5 ] ])
S4_75 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 3, 4, 5 ] ])
S4_76 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 3 ] ])
S4_77 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ] ])
S4_78 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ] ])
S4_79 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ] ])
S4_80 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 2, 4 ] ])
S4_81 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ] ])
S4_82 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ] ])
S4_83 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 3, 5 ] ])
S4_84 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 3, 4, 5 ] ])
S4_85 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 2, 3 ] ])
S4_86 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_87 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_88 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 3, 4, 5 ] ])
S4_89 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 1, 2, 3 ] ])
S4_90 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 1, 2, 4 ] ])
S4_91 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ] ])
S4_92 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_93 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])
S4_94 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 2, 4, 5 ] ])
S4_95 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 2, 3, 5 ] ])
S4_96 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 4 ], [ 3, 4, 5 ] ])
S4_97 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_98 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 4, 5 ], [ 2, 4, 5 ] ])
S4_99 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 4, 5 ], [ 3, 4, 5 ] ])
S4_100 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 4, 5 ], [ 1, 2, 3 ] ])
S4_101 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_102 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_103 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_104 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_105 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_106 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ] ])
S4_107 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_108 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ] ])
S4_109 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ] ])
S4_110 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ] ])
S4_111 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 2, 3 ] ])
S4_112 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_113 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_114 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_115 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_116 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ] ])
S4_117 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_118 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_119 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 3, 4, 5 ] ])
S4_120 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 3, 5 ], [ 0, 4, 5 ] ])
S4_121 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 3, 5 ], [ 2, 4, 5 ] ])
S4_122 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_123 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_124 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_125 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_126 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 0, 4, 5 ], [ 2, 4, 5 ] ])
S4_127 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_128 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 0, 2, 3 ] ])
S4_129 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ] ])
S4_130 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_131 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_132 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_133 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 3, 4, 5 ] ])
S4_134 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 2, 3 ] ])
S4_135 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ] ])
S4_136 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 2, 4, 5 ] ])
S4_137 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_138 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])
S4_139 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ] ])
S4_140 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ] ])
S4_141 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 2, 3, 5 ] ])
S4_142 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 3, 4, 5 ] ])
S4_143 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ] ])
S4_144 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 4 ], [ 2, 3, 5 ] ])
S4_145 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ], [ 2, 3, 5 ] ])
S4_146 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ], [ 3, 4, 5 ] ])
S4_147 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ], [ 1, 2, 3 ] ])
S4_148 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_149 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_150 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_151 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_152 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ] ])
S4_153 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ] ])
S4_154 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ] ])
S4_155 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ] ])
S4_156 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 2, 3 ] ])
S4_157 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ] ])
S4_158 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 2, 4, 5 ] ])
S4_159 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_160 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 1, 2, 4 ] ])
S4_161 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ] ])
S4_162 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 2, 3, 5 ] ])
S4_163 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 3, 4, 5 ] ])
S4_164 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ] ])
S4_165 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_166 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ], [ 2, 4, 5 ] ])
S4_167 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ], [ 3, 4, 5 ] ])
S4_168 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ], [ 1, 2, 3 ] ])
S4_169 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_170 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_171 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_172 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_173 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_174 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 3, 4, 5 ] ])
S4_175 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_176 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_177 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ] ])
S4_178 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_179 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_180 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_181 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_182 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 3 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_183 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_184 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_185 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 0, 2, 3 ] ])
S4_186 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 1, 2, 3 ] ])
S4_187 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 2, 3 ], [ 0, 4, 5 ] ])
S4_188 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_189 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 0, 2, 3 ] ])
S4_190 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_191 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 2, 4, 5 ] ])
S4_192 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 2, 3, 5 ] ])
S4_193 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_194 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_195 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 3, 5 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_196 = 5 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ] ])
S4_197 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ] ])
S4_198 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 3, 5 ] ])
S4_199 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 3, 4, 5 ] ])
S4_200 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 1, 2, 3 ] ])
S4_201 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 3, 5 ] ])
S4_202 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 3, 4, 5 ] ])
S4_203 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_204 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_205 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_206 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_207 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ] ])
S4_208 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 3, 5 ] ])
S4_209 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ] ])
S4_210 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_211 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_212 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_213 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 1, 2, 4 ], [ 2, 3, 5 ] ])
S4_214 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ], [ 2, 4, 5 ] ])
S4_215 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ], [ 2, 3, 5 ] ])
S4_216 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_217 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_218 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_219 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_220 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_221 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 4, 5 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_222 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_223 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ] ])
S4_224 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 3, 5 ] ])
S4_225 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 1, 2, 3 ] ])
S4_226 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 4, 5 ] ])
S4_227 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 1, 2, 3 ] ])
S4_228 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_229 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_230 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_231 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ] ])
S4_232 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 1, 2, 3 ] ])
S4_233 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_234 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_235 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 3 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_236 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_237 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_238 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_239 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_240 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_241 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 3, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_242 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_243 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_244 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_245 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_246 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_247 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_248 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_249 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 2, 3, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_250 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_251 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_252 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ], [ 1, 2, 3 ] ])
S4_253 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_254 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_255 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 3 ], [ 0, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ] ])
S4_256 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ] ])
S4_257 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_258 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ] ])
S4_259 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 2, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_260 = 3 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_261 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 1, 4, 5 ], [ 2, 4, 5 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_262 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 3, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])
S4_263 = 1 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 0, 2, 5 ], [ 1, 4, 5 ], [ 1, 2, 4 ], [ 2, 4, 5 ], [ 2, 3, 5 ], [ 1, 2, 3 ] ])
S4_264 = 2 * ThreeGraphTheory(6,edges =[ [ 0, 1, 4 ], [ 0, 1, 3 ], [ 0, 1, 2 ], [ 0, 1, 5 ], [ 0, 3, 4 ], [ 1, 3, 5 ], [ 2, 3, 4 ], [ 1, 2, 5 ], [ 0, 2, 4 ], [ 0, 4, 5 ], [ 2, 4, 5 ], [ 3, 4, 5 ], [ 1, 2, 3 ] ])

ThreeGraphTheory.optimize(S4+S4_0 + S4_1 + S4_2 + S4_3 + S4_4 + S4_5 + S4_6 + S4_7 + S4_8 + S4_9 + S4_10 + S4_11 + S4_12 + S4_13 + S4_14 + S4_15 + S4_16 + S4_17 + S4_18 + S4_19 + S4_20 + S4_21 + S4_22 + S4_23 + S4_24 + S4_25 + S4_26 + S4_27 + S4_28 + S4_29 + S4_30 + S4_31 + S4_32 + S4_33 + S4_34 + S4_35 + S4_36 + S4_37 + S4_38 + S4_39 + S4_40 + S4_41 + S4_42 + S4_43 + S4_44 + S4_45 + S4_46 + S4_47 + S4_48 + S4_49 + S4_50 + S4_51 + S4_52 + S4_53 + S4_54 + S4_55 + S4_56 + S4_57 + S4_58 + S4_59 + S4_60 + S4_61 + S4_62 + S4_63 + S4_64 + S4_65 + S4_66 + S4_67 + S4_68 + S4_69 + S4_70 + S4_71 + S4_72 + S4_73 + S4_74 + S4_75 + S4_76 + S4_77 + S4_78 + S4_79 + S4_80 + S4_81 + S4_82 + S4_83 + S4_84 + S4_85 + S4_86 + S4_87 + S4_88 + S4_89 + S4_90 + S4_91 + S4_92 + S4_93 + S4_94 + S4_95 + S4_96 + S4_97 + S4_98 + S4_99 + S4_100 + S4_101 + S4_102 + S4_103 + S4_104 + S4_105 + S4_106 + S4_107 + S4_108 + S4_109 + S4_110 + S4_111 + S4_112 + S4_113 + S4_114 + S4_115 + S4_116 + S4_117 + S4_118 + S4_119 + S4_120 + S4_121 + S4_122 + S4_123 + S4_124 + S4_125 + S4_126 + S4_127 + S4_128 + S4_129 + S4_130 + S4_131 + S4_132 + S4_133 + S4_134 + S4_135 + S4_136 + S4_137 + S4_138 + S4_139 + S4_140 + S4_141 + S4_142 + S4_143 + S4_144 + S4_145 + S4_146 + S4_147 + S4_148 + S4_149 + S4_150 + S4_151 + S4_152 + S4_153 + S4_154 + S4_155 + S4_156 + S4_157 + S4_158 + S4_159 + S4_160 + S4_161 + S4_162 + S4_163 + S4_164 + S4_165 + S4_166 + S4_167 + S4_168 + S4_169 + S4_170 + S4_171 + S4_172 + S4_173 + S4_174 + S4_175 + S4_176 + S4_177 + S4_178 + S4_179 + S4_180 + S4_181 + S4_182 + S4_183 + S4_184 + S4_185 + S4_186 + S4_187 + S4_188 + S4_189 + S4_190 + S4_191 + S4_192 + S4_193 + S4_194 + S4_195 + S4_196 + S4_197 + S4_198 + S4_199 + S4_200 + S4_201 + S4_202 + S4_203 + S4_204 + S4_205 + S4_206 + S4_207 + S4_208 + S4_209 + S4_210 + S4_211 + S4_212 + S4_213 + S4_214 + S4_215 + S4_216 + S4_217 + S4_218 + S4_219 + S4_220 + S4_221 + S4_222 + S4_223 + S4_224 + S4_225 + S4_226 + S4_227 + S4_228 + S4_229 + S4_230 + S4_231 + S4_232 + S4_233 + S4_234 + S4_235 + S4_236 + S4_237 + S4_238 + S4_239 + S4_240 + S4_241 + S4_242 + S4_243 + S4_244 + S4_245 + S4_246 + S4_247 + S4_248 + S4_249 + S4_250 + S4_251 + S4_252 + S4_253 + S4_254 + S4_255 + S4_256 + S4_257 + S4_258 + S4_259 + S4_260 + S4_261 + S4_262 + S4_263 + S4_264,
                          6,  exact=True,  file="K43_S4", denom=1024*1024, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 964
# The relevant ftypes are constructed, their number is 5
# Block sizes before symmetric/asymmetric change is applied: [11, 64, 56, 50, 45]
# Done with mult table for Ftype on 4 points with edges=(012 013 023): : 5it [00:00, 17.22it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [8, 3, 11, 53, 16, 40, 22, 28, 14, 31, -964, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 8.12e-01 Pobj: -1.7429148e+02 Ad: 1.41e-01 Dobj: -4.2212318e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -2.2895024e+02 Ad: 8.52e-01 Dobj: -2.1714672e+01
# Iter:  3 Ap: 1.00e+00 Pobj: -2.3701132e+02 Ad: 9.36e-01 Dobj: -2.6052834e+00
# Iter:  4 Ap: 1.00e+00 Pobj: -2.1555158e+02 Ad: 9.46e-01 Dobj: -6.3860208e-01
# Iter:  5 Ap: 7.68e-01 Pobj: -1.9758464e+02 Ad: 7.89e-01 Dobj: -4.3811822e-01
# Iter:  6 Ap: 1.00e+00 Pobj: -2.0796690e+02 Ad: 5.91e-01 Dobj: -4.2946658e-01
# ...
