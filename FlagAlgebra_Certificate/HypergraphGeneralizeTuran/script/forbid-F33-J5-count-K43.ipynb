# %%
F33 = ThreeGraphTheory.p(6, edges=[[0,1,2], [0,3,4], [0,3,5], [0,4,5], [1,3,4], [1,3,5], [1,4,5], [2,3,4], [2,3,5], [2,4,5]])
J5 = ThreeGraphTheory.p(6, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,1,5], [0,2,3],[0,2,4], [0,2,5],[0,3,4],[0,3,5],[0,4,5]])
ThreeGraphTheory.exclude([F33,J5])

print("Number of structures without")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without
# and size 5:  34
# and size 6:  2053

# %%
K43 = ThreeGraphTheory(4, edges=[[0, 1, 2], [0,1,3],[0,2,3],[1,2,3]])

ThreeGraphTheory.optimize(K43, 6,  exact=True,  file="F33J5_K43", 
              denom=1024*1024, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 2053
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 64, 64, 64, 64]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:08,  1.37s/it]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 20, 44, 28, 36, 20, 44, 11, 53, -2053, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 5.52e-01 Pobj: -5.6861698e+01 Ad: 2.12e-01 Dobj: -1.6481372e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.4357057e+02 Ad: 6.70e-01 Dobj: -4.4335193e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -1.5425774e+02 Ad: 8.96e-01 Dobj: -6.8819752e-01
# Iter:  4 Ap: 1.00e+00 Pobj: -1.4789917e+02 Ad: 9.35e-01 Dobj: -1.9328031e-01
# Iter:  5 Ap: 7.25e-01 Pobj: -1.5077106e+02 Ad: 9.04e-01 Dobj: -1.0731721e-01
# ...
