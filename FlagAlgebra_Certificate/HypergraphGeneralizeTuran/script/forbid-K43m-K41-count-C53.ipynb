# %%
K43m = ThreeGraphTheory.p(4, edges=[[0, 1, 2], [0,1,3],[0,2,3]])
K41 = ThreeGraphTheory(4, edges=[[0, 1, 2]])

ThreeGraphTheory.exclude([K43m,K41])

print("Number of structures without K43m and K41")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without K43m and K41
# and size 5:  4
# and size 6:  6

# %%
C53 = ThreeGraphTheory(5, edges=[[0, 1, 2], [1, 2, 3], [2, 3, 4], [3, 4, 0],[0,1,4]])

symbolic_constr = ThreeGraphTheory.blowup_construction(8, [1/6, 1/6,1/6,1/6, 1/6,1/6], edges=[[0,1,2],[1,2,3],[2,3,4],[0,3,4],[0,1,4],[0,2,5],[1,3,5],[1,4,5],[2,4,5],[0,3,5]])

ThreeGraphTheory.optimize(C53, 8,  exact=True,  file="K43mK41_C53", construction=symbolic_constr, 
              denom=1024*15*3*5, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 14
# The relevant ftypes are constructed, their number is 9
# Block sizes before symmetric/asymmetric change is applied: [11, 41, 20, 32, 17, 11, 8, 9, 6]
# Done with mult table for Ftype on 6 points with edges=(014 015 023 024 035 123 125 134 245 345): : 9it [00:00, 789.69it/s]
# Tables finished
# Constraints finished
# Adjusting table with kernels from construction
# Running SDP after kernel correction. Used block sizes are [7, 2, 5, 22, 8, 10, 1, 8, 3, 3, 4, 3, 5, 5, -14, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 1.00e+00 Pobj: -1.7232903e+01 Ad: 7.14e-01 Dobj:  8.5413440e-01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.7543575e+01 Ad: 9.47e-01 Dobj: -4.1353671e-02
# Iter:  3 Ap: 1.00e+00 Pobj: -1.1496783e+01 Ad: 9.09e-01 Dobj: -6.5914472e-02
# Iter:  4 Ap: 8.39e-01 Pobj: -4.6985177e+00 Ad: 7.45e-01 Dobj: -5.4163898e-02
# ...
