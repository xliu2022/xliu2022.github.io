# %%
K53 = ThreeGraphTheory(5, edges=[[0, 1, 2], [0,1,3], [0,1,4], [0,2,3],[0,2,4],[0,3,4],[1,2,3],[1,2,4],[1,3,4],[2,3,4]])
K63mm = ThreeGraphTheory.p(6, edges=[ [0,1,4],[0,1,5], [0,2,3],[0,2,4],[0,2,5],[0,3,4],[0,3,5],[0,4,5],
                                 [1,2,3],[1,2,4],[1,2,5],[1,3,4],[1,3,5],[1,4,5],
                                 [2,3,4],[2,3,5],[2,4,5],[3,4,5]])

ThreeGraphTheory.exclude([K63mm])

print("Number of structures without K63mm")
print("and size 5: ", len(ThreeGraphTheory.generate(5)))
print("and size 6: ", len(ThreeGraphTheory.generate(6)))
# Out:
# Number of structures without K63mm
# and size 5:  34
# and size 6:  2133

# %%
K43 = ThreeGraphTheory(4, edges=[[0, 1, 2], [0,1,3],[0,2,3],[1,2,3]])

ThreeGraphTheory.optimize(K43, 6,  exact=True,  file="K63mm_K43", 
              denom=1024*1024, slack_threshold=1e-6
             )
# Out:
# Base flags generated, their number is 2133
# The relevant ftypes are constructed, their number is 6
# Block sizes before symmetric/asymmetric change is applied: [12, 64, 64, 64, 64, 64]
# Done with mult table for Ftype on 4 points with edges=(012 013 023 123): : 6it [00:00,  7.38it/s]
# Tables finished
# Constraints finished
# Running sdp without construction. Used block sizes are [9, 3, 11, 53, 20, 44, 28, 36, 20, 44, 11, 53, -2133, -2]
# CSDP 6.2.0
# Iter:  0 Ap: 0.00e+00 Pobj:  0.0000000e+00 Ad: 0.00e+00 Dobj:  0.0000000e+00
# Iter:  1 Ap: 3.65e-01 Pobj: -3.9379009e+01 Ad: 1.78e-01 Dobj: -2.1596613e+01
# Iter:  2 Ap: 1.00e+00 Pobj: -1.4421020e+02 Ad: 6.31e-01 Dobj: -3.2030683e+00
# Iter:  3 Ap: 1.00e+00 Pobj: -1.5795249e+02 Ad: 8.76e-01 Dobj: -1.1189524e+00
# Iter:  4 Ap: 1.00e+00 Pobj: -1.5598204e+02 Ad: 9.18e-01 Dobj: -2.8415527e-01
# Iter:  5 Ap: 9.73e-01 Pobj: -1.5441255e+02 Ad: 8.47e-01 Dobj: -1.7074921e-01
# ...
